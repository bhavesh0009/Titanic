# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn import preprocessing
from sklearn.tree import export_graphviz
# %matplotlib inline

# %%
def score_in_percent (a,b):
    return (sum(a==b)*100)/len(a)

# %%
train = pd.read_csv("C:\\Users\\user\\Titanic\\train.csv")
test =  pd.read_csv("C:\\Users\\user\\Titanic\\test.csv")

# %%
# store it as Y
Y_train = train["Survived"]
train.drop(["Survived"], axis=1, inplace=True)

# %%
num_train = len(train)
all_data = pd.concat([train, test])

# %%
all_data.describe()
# Out:
#        PassengerId       Pclass          Age        SibSp        Parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean    655.000000     2.294882    29.881138     0.498854     0.385027
# std     378.020061     0.837836    14.413493     1.041658     0.865560
# min       1.000000     1.000000     0.170000     0.000000     0.000000
# 25%     328.000000     2.000000    21.000000     0.000000     0.000000
# 50%     655.000000     3.000000    28.000000     0.000000     0.000000
# 75%     982.000000     3.000000    39.000000     1.000000     0.000000
# max    1309.000000     3.000000    80.000000     8.000000     9.000000
#
#               Fare
# count  1308.000000
# mean     33.295479
# std      51.758668
# min       0.000000
# 25%       7.895800
# 50%      14.454200
# 75%      31.275000
# max     512.329200

# %%
all_data.describe(include=['O'])
# Out:
#                         Name   Sex    Ticket        Cabin Embarked
# count                   1309  1309      1309          295     1307
# unique                  1307     2       929          186        3
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S
# freq                       2   843        11            6      914

# %%
# Populating null fare value with median of train set
all_data["Fare"]=all_data["Fare"].fillna(train["Fare"].median())
# Populating null age value with median of train set
all_data["Age"]=all_data["Age"].fillna(train["Age"].median())
# Populating missing embarked with most frequent value - S
all_data["Embarked"]=all_data["Embarked"].fillna("S")
# Creating new feature as Title
all_data['Title'] = all_data.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
# Drop cabin due to too many null values
all_data.drop(["Cabin","Name","Ticket","PassengerId"], axis=1, inplace=True)
# Converting sex into binary
sex_mapping = {"male": 0, "female": 1}
all_data['Sex'] = all_data['Sex'].map(sex_mapping)

# %%
all_data = pd.get_dummies(all_data)

# %%
X_train = all_data[:num_train]
X_test = all_data[num_train:]

# %%
X_train, X_cv, y_train, y_cv = train_test_split( X_train, Y_train, test_size = 0.3, random_state = 100)

# %%
clf_gini = DecisionTreeClassifier(criterion = "gini", random_state = 100,
                               max_depth=6, min_samples_leaf=5)
clf_gini.fit(X_train, y_train)
y_pred = clf_gini.predict(X_cv)
score_in_percent(y_pred,y_cv)
# Out:
# 80.223880597014926

# %%
# This statement builds a dot file.
cols = list(X_train.columns.values)
tree.export_graphviz(clf_gini, out_file='treedummies.dot',feature_names  = cols)

# %%
y_test_pred = clf_gini.predict(X_test)

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": y_test_pred
    })
submission.to_csv('treedummies.csv', index=False) # LB : 0.78469

# %%
# Let's do some feature engineering now and add few features
# Adding total family size and droppign parch and sibsp.
X_train['FamSi'] = X_train["SibSp"] + X_train["Parch"] 
X_cv['FamSi']    = X_cv["SibSp"] + X_cv["Parch"] 
X_test['FamSi']    = X_test["SibSp"] + X_test["Parch"] 
X_train.drop(["SibSp","Parch"], axis=1, inplace=True)
X_cv.drop(["SibSp","Parch"], axis=1, inplace=True)
X_test.drop(["SibSp","Parch"], axis=1, inplace=True)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
clf_gini = DecisionTreeClassifier(criterion = "entropy", random_state = 100,
                               max_depth=3, min_samples_leaf=5)
clf_gini.fit(X_train, y_train)
y_pred = clf_gini.predict(X_cv)
score_in_percent(y_pred,y_cv)
# Out:
# 80.97014925373135

# %%
# This statement builds a dot file.
cols = list(X_train.columns.values)
tree.export_graphviz(clf_gini, out_file='treewithlargetrainfemsi.dot',feature_names  = cols)

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": y_test_pred
    })
submission.to_csv('submission_with_3depth_larger_train_famsi.csv', index=False) # LB : 0.74163

# %%
X_train.to_csv("X_train.csv", index=False)

# %%
X_subset = pd.concat([X_train, y_train],axis=1)

# %%
X_subset.to_csv("X_subset.csv", index=False)

# %%
# Decision tree tuning
for crtr in ['gini','entropy']:
    for md in [3,4,5,6,7,8,9,10]:
        for spltr in ['best','random']:
            for mss in [6,10,16,26,42]:
                for msl in [6,10,16,26,42]:
                    dts = DecisionTreeClassifier(class_weight=None, criterion=crtr, max_depth=md,
                                max_features=None, max_leaf_nodes=None, min_samples_leaf=msl,
                                min_samples_split=mss, min_weight_fraction_leaf=0.0,
                                presort=False, random_state=100, splitter=spltr)
                    dts.fit(X_train, y_train)
                    y_pred = dts.predict(X_cv)
                    sip=score_in_percent(y_pred,y_cv)
                    print("score for {} criterion, {} max_depth, {} splitter, {} min_samples_split, {} min_samples_leaf is {}".format(crtr,md,spltr,mss,msl,sip))
# Out:
# score for gini criterion, 3 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for gini criterion, 3 max_depth, best splitter, 6 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 3 max_depth, best splitter, 6 min_samples_split, 16 min_samples_leaf is 79.4776119402985
# score for gini criterion, 3 max_depth, best splitter, 6 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 3 max_depth, best splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 3 max_depth, best splitter, 10 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for gini criterion, 3 max_depth, best splitter, 10 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 3 max_depth, best splitter, 10 min_samples_split, 16 min_samples_leaf is 79.4776119402985
# score for gini criterion, 3 max_depth, best splitter, 10 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 3 max_depth, best splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 3 max_depth, best splitter, 16 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for gini criterion, 3 max_depth, best splitter, 16 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 3 max_depth, best splitter, 16 min_samples_split, 16 min_samples_leaf is 79.4776119402985
# score for gini criterion, 3 max_depth, best splitter, 16 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 3 max_depth, best splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 3 max_depth, best splitter, 26 min_samples_split, 6 min_samples_leaf is 79.4776119402985
# score for gini criterion, 3 max_depth, best splitter, 26 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 3 max_depth, best splitter, 26 min_samples_split, 16 min_samples_leaf is 79.4776119402985
# score for gini criterion, 3 max_depth, best splitter, 26 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 3 max_depth, best splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 3 max_depth, best splitter, 42 min_samples_split, 6 min_samples_leaf is 79.4776119402985
# score for gini criterion, 3 max_depth, best splitter, 42 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 3 max_depth, best splitter, 42 min_samples_split, 16 min_samples_leaf is 79.4776119402985
# score for gini criterion, 3 max_depth, best splitter, 42 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 3 max_depth, best splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 3 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 82.08955223880596
# score for gini criterion, 3 max_depth, random splitter, 6 min_samples_split, 10 min_samples_leaf is 82.08955223880596
# score for gini criterion, 3 max_depth, random splitter, 6 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 3 max_depth, random splitter, 6 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 3 max_depth, random splitter, 6 min_samples_split, 42 min_samples_leaf is 76.11940298507463
# score for gini criterion, 3 max_depth, random splitter, 10 min_samples_split, 6 min_samples_leaf is 82.08955223880596
# score for gini criterion, 3 max_depth, random splitter, 10 min_samples_split, 10 min_samples_leaf is 82.08955223880596
# score for gini criterion, 3 max_depth, random splitter, 10 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 3 max_depth, random splitter, 10 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 3 max_depth, random splitter, 10 min_samples_split, 42 min_samples_leaf is 76.11940298507463
# score for gini criterion, 3 max_depth, random splitter, 16 min_samples_split, 6 min_samples_leaf is 82.08955223880596
# score for gini criterion, 3 max_depth, random splitter, 16 min_samples_split, 10 min_samples_leaf is 82.08955223880596
# score for gini criterion, 3 max_depth, random splitter, 16 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 3 max_depth, random splitter, 16 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 3 max_depth, random splitter, 16 min_samples_split, 42 min_samples_leaf is 76.11940298507463
# score for gini criterion, 3 max_depth, random splitter, 26 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 3 max_depth, random splitter, 26 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 3 max_depth, random splitter, 26 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 3 max_depth, random splitter, 26 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 3 max_depth, random splitter, 26 min_samples_split, 42 min_samples_leaf is 76.11940298507463
# score for gini criterion, 3 max_depth, random splitter, 42 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 3 max_depth, random splitter, 42 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 3 max_depth, random splitter, 42 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 3 max_depth, random splitter, 42 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 3 max_depth, random splitter, 42 min_samples_split, 42 min_samples_leaf is 76.11940298507463
# score for gini criterion, 4 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 4 max_depth, best splitter, 6 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, best splitter, 6 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, best splitter, 6 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 4 max_depth, best splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 4 max_depth, best splitter, 10 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 4 max_depth, best splitter, 10 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, best splitter, 10 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, best splitter, 10 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 4 max_depth, best splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 4 max_depth, best splitter, 16 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 4 max_depth, best splitter, 16 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, best splitter, 16 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, best splitter, 16 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 4 max_depth, best splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 4 max_depth, best splitter, 26 min_samples_split, 6 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, best splitter, 26 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, best splitter, 26 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, best splitter, 26 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 4 max_depth, best splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 4 max_depth, best splitter, 42 min_samples_split, 6 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, best splitter, 42 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, best splitter, 42 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, best splitter, 42 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 4 max_depth, best splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 4 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 82.46268656716418
# score for gini criterion, 4 max_depth, random splitter, 6 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 4 max_depth, random splitter, 6 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 4 max_depth, random splitter, 6 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, random splitter, 6 min_samples_split, 42 min_samples_leaf is 76.11940298507463
# score for gini criterion, 4 max_depth, random splitter, 10 min_samples_split, 6 min_samples_leaf is 82.46268656716418
# score for gini criterion, 4 max_depth, random splitter, 10 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 4 max_depth, random splitter, 10 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 4 max_depth, random splitter, 10 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, random splitter, 10 min_samples_split, 42 min_samples_leaf is 76.11940298507463
# score for gini criterion, 4 max_depth, random splitter, 16 min_samples_split, 6 min_samples_leaf is 82.46268656716418
# score for gini criterion, 4 max_depth, random splitter, 16 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 4 max_depth, random splitter, 16 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 4 max_depth, random splitter, 16 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, random splitter, 16 min_samples_split, 42 min_samples_leaf is 76.11940298507463
# score for gini criterion, 4 max_depth, random splitter, 26 min_samples_split, 6 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, random splitter, 26 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 4 max_depth, random splitter, 26 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 4 max_depth, random splitter, 26 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, random splitter, 26 min_samples_split, 42 min_samples_leaf is 76.11940298507463
# score for gini criterion, 4 max_depth, random splitter, 42 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 4 max_depth, random splitter, 42 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 4 max_depth, random splitter, 42 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 4 max_depth, random splitter, 42 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 4 max_depth, random splitter, 42 min_samples_split, 42 min_samples_leaf is 76.11940298507463
# score for gini criterion, 5 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 5 max_depth, best splitter, 6 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, best splitter, 6 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, best splitter, 6 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, best splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, best splitter, 10 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 5 max_depth, best splitter, 10 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, best splitter, 10 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, best splitter, 10 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, best splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, best splitter, 16 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 5 max_depth, best splitter, 16 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, best splitter, 16 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, best splitter, 16 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, best splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, best splitter, 26 min_samples_split, 6 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, best splitter, 26 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, best splitter, 26 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, best splitter, 26 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, best splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, best splitter, 42 min_samples_split, 6 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, best splitter, 42 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, best splitter, 42 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, best splitter, 42 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, best splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for gini criterion, 5 max_depth, random splitter, 6 min_samples_split, 10 min_samples_leaf is 79.85074626865672
# score for gini criterion, 5 max_depth, random splitter, 6 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 5 max_depth, random splitter, 6 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, random splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, random splitter, 10 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for gini criterion, 5 max_depth, random splitter, 10 min_samples_split, 10 min_samples_leaf is 79.85074626865672
# score for gini criterion, 5 max_depth, random splitter, 10 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 5 max_depth, random splitter, 10 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, random splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, random splitter, 16 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for gini criterion, 5 max_depth, random splitter, 16 min_samples_split, 10 min_samples_leaf is 79.85074626865672
# score for gini criterion, 5 max_depth, random splitter, 16 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 5 max_depth, random splitter, 16 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, random splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, random splitter, 26 min_samples_split, 6 min_samples_leaf is 78.73134328358209
# score for gini criterion, 5 max_depth, random splitter, 26 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 5 max_depth, random splitter, 26 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 5 max_depth, random splitter, 26 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, random splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, random splitter, 42 min_samples_split, 6 min_samples_leaf is 78.35820895522389
# score for gini criterion, 5 max_depth, random splitter, 42 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 5 max_depth, random splitter, 42 min_samples_split, 16 min_samples_leaf is 79.4776119402985
# score for gini criterion, 5 max_depth, random splitter, 42 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 5 max_depth, random splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 6 max_depth, best splitter, 6 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 6 max_depth, best splitter, 6 min_samples_split, 16 min_samples_leaf is 77.61194029850746
# score for gini criterion, 6 max_depth, best splitter, 6 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, best splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, best splitter, 10 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 6 max_depth, best splitter, 10 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 6 max_depth, best splitter, 10 min_samples_split, 16 min_samples_leaf is 77.61194029850746
# score for gini criterion, 6 max_depth, best splitter, 10 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, best splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, best splitter, 16 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 6 max_depth, best splitter, 16 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 6 max_depth, best splitter, 16 min_samples_split, 16 min_samples_leaf is 77.61194029850746
# score for gini criterion, 6 max_depth, best splitter, 16 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, best splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, best splitter, 26 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 6 max_depth, best splitter, 26 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 6 max_depth, best splitter, 26 min_samples_split, 16 min_samples_leaf is 77.61194029850746
# score for gini criterion, 6 max_depth, best splitter, 26 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, best splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, best splitter, 42 min_samples_split, 6 min_samples_leaf is 79.85074626865672
# score for gini criterion, 6 max_depth, best splitter, 42 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 6 max_depth, best splitter, 42 min_samples_split, 16 min_samples_leaf is 77.61194029850746
# score for gini criterion, 6 max_depth, best splitter, 42 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, best splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 79.85074626865672
# score for gini criterion, 6 max_depth, random splitter, 6 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 6 max_depth, random splitter, 6 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 6 max_depth, random splitter, 6 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 6 max_depth, random splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, random splitter, 10 min_samples_split, 6 min_samples_leaf is 79.85074626865672
# score for gini criterion, 6 max_depth, random splitter, 10 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 6 max_depth, random splitter, 10 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 6 max_depth, random splitter, 10 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 6 max_depth, random splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, random splitter, 16 min_samples_split, 6 min_samples_leaf is 79.85074626865672
# score for gini criterion, 6 max_depth, random splitter, 16 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 6 max_depth, random splitter, 16 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 6 max_depth, random splitter, 16 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 6 max_depth, random splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, random splitter, 26 min_samples_split, 6 min_samples_leaf is 77.61194029850746
# score for gini criterion, 6 max_depth, random splitter, 26 min_samples_split, 10 min_samples_leaf is 79.1044776119403
# score for gini criterion, 6 max_depth, random splitter, 26 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 6 max_depth, random splitter, 26 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 6 max_depth, random splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 6 max_depth, random splitter, 42 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 6 max_depth, random splitter, 42 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 6 max_depth, random splitter, 42 min_samples_split, 16 min_samples_leaf is 80.59701492537313
# score for gini criterion, 6 max_depth, random splitter, 42 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 6 max_depth, random splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 80.97014925373135
# score for gini criterion, 7 max_depth, best splitter, 6 min_samples_split, 10 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 6 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 7 max_depth, best splitter, 6 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 10 min_samples_split, 6 min_samples_leaf is 80.97014925373135
# score for gini criterion, 7 max_depth, best splitter, 10 min_samples_split, 10 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 10 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 7 max_depth, best splitter, 10 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 16 min_samples_split, 6 min_samples_leaf is 80.97014925373135
# score for gini criterion, 7 max_depth, best splitter, 16 min_samples_split, 10 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 16 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 7 max_depth, best splitter, 16 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 26 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 7 max_depth, best splitter, 26 min_samples_split, 10 min_samples_leaf is 78.73134328358209
# score for gini criterion, 7 max_depth, best splitter, 26 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 7 max_depth, best splitter, 26 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 42 min_samples_split, 6 min_samples_leaf is 79.85074626865672
# score for gini criterion, 7 max_depth, best splitter, 42 min_samples_split, 10 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 42 min_samples_split, 16 min_samples_leaf is 77.61194029850746
# score for gini criterion, 7 max_depth, best splitter, 42 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, best splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for gini criterion, 7 max_depth, random splitter, 6 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 7 max_depth, random splitter, 6 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 7 max_depth, random splitter, 6 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 7 max_depth, random splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, random splitter, 10 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for gini criterion, 7 max_depth, random splitter, 10 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 7 max_depth, random splitter, 10 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 7 max_depth, random splitter, 10 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 7 max_depth, random splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, random splitter, 16 min_samples_split, 6 min_samples_leaf is 79.4776119402985
# score for gini criterion, 7 max_depth, random splitter, 16 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 7 max_depth, random splitter, 16 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 7 max_depth, random splitter, 16 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 7 max_depth, random splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, random splitter, 26 min_samples_split, 6 min_samples_leaf is 79.4776119402985
# score for gini criterion, 7 max_depth, random splitter, 26 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 7 max_depth, random splitter, 26 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 7 max_depth, random splitter, 26 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 7 max_depth, random splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 7 max_depth, random splitter, 42 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 7 max_depth, random splitter, 42 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 7 max_depth, random splitter, 42 min_samples_split, 16 min_samples_leaf is 80.59701492537313
# score for gini criterion, 7 max_depth, random splitter, 42 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 7 max_depth, random splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 81.34328358208955
# score for gini criterion, 8 max_depth, best splitter, 6 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 8 max_depth, best splitter, 6 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 8 max_depth, best splitter, 6 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, best splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, best splitter, 10 min_samples_split, 6 min_samples_leaf is 81.34328358208955
# score for gini criterion, 8 max_depth, best splitter, 10 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 8 max_depth, best splitter, 10 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 8 max_depth, best splitter, 10 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, best splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, best splitter, 16 min_samples_split, 6 min_samples_leaf is 80.97014925373135
# score for gini criterion, 8 max_depth, best splitter, 16 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 8 max_depth, best splitter, 16 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 8 max_depth, best splitter, 16 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, best splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, best splitter, 26 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 8 max_depth, best splitter, 26 min_samples_split, 10 min_samples_leaf is 79.85074626865672
# score for gini criterion, 8 max_depth, best splitter, 26 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 8 max_depth, best splitter, 26 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, best splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, best splitter, 42 min_samples_split, 6 min_samples_leaf is 79.85074626865672
# score for gini criterion, 8 max_depth, best splitter, 42 min_samples_split, 10 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, best splitter, 42 min_samples_split, 16 min_samples_leaf is 77.61194029850746
# score for gini criterion, 8 max_depth, best splitter, 42 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, best splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 77.98507462686567
# score for gini criterion, 8 max_depth, random splitter, 6 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 8 max_depth, random splitter, 6 min_samples_split, 16 min_samples_leaf is 80.59701492537313
# score for gini criterion, 8 max_depth, random splitter, 6 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 8 max_depth, random splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, random splitter, 10 min_samples_split, 6 min_samples_leaf is 77.98507462686567
# score for gini criterion, 8 max_depth, random splitter, 10 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 8 max_depth, random splitter, 10 min_samples_split, 16 min_samples_leaf is 80.59701492537313
# score for gini criterion, 8 max_depth, random splitter, 10 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 8 max_depth, random splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, random splitter, 16 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for gini criterion, 8 max_depth, random splitter, 16 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 8 max_depth, random splitter, 16 min_samples_split, 16 min_samples_leaf is 80.59701492537313
# score for gini criterion, 8 max_depth, random splitter, 16 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 8 max_depth, random splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, random splitter, 26 min_samples_split, 6 min_samples_leaf is 78.73134328358209
# score for gini criterion, 8 max_depth, random splitter, 26 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 8 max_depth, random splitter, 26 min_samples_split, 16 min_samples_leaf is 80.59701492537313
# score for gini criterion, 8 max_depth, random splitter, 26 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 8 max_depth, random splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 8 max_depth, random splitter, 42 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 8 max_depth, random splitter, 42 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 8 max_depth, random splitter, 42 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 8 max_depth, random splitter, 42 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 8 max_depth, random splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 79.4776119402985
# score for gini criterion, 9 max_depth, best splitter, 6 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 9 max_depth, best splitter, 6 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 9 max_depth, best splitter, 6 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, best splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, best splitter, 10 min_samples_split, 6 min_samples_leaf is 79.4776119402985
# score for gini criterion, 9 max_depth, best splitter, 10 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 9 max_depth, best splitter, 10 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 9 max_depth, best splitter, 10 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, best splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, best splitter, 16 min_samples_split, 6 min_samples_leaf is 79.1044776119403
# score for gini criterion, 9 max_depth, best splitter, 16 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 9 max_depth, best splitter, 16 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 9 max_depth, best splitter, 16 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, best splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, best splitter, 26 min_samples_split, 6 min_samples_leaf is 79.4776119402985
# score for gini criterion, 9 max_depth, best splitter, 26 min_samples_split, 10 min_samples_leaf is 79.85074626865672
# score for gini criterion, 9 max_depth, best splitter, 26 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 9 max_depth, best splitter, 26 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, best splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, best splitter, 42 min_samples_split, 6 min_samples_leaf is 79.1044776119403
# score for gini criterion, 9 max_depth, best splitter, 42 min_samples_split, 10 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, best splitter, 42 min_samples_split, 16 min_samples_leaf is 77.61194029850746
# score for gini criterion, 9 max_depth, best splitter, 42 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, best splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for gini criterion, 9 max_depth, random splitter, 6 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 9 max_depth, random splitter, 6 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 9 max_depth, random splitter, 6 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 9 max_depth, random splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, random splitter, 10 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for gini criterion, 9 max_depth, random splitter, 10 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 9 max_depth, random splitter, 10 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 9 max_depth, random splitter, 10 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 9 max_depth, random splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, random splitter, 16 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 9 max_depth, random splitter, 16 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 9 max_depth, random splitter, 16 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 9 max_depth, random splitter, 16 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 9 max_depth, random splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, random splitter, 26 min_samples_split, 6 min_samples_leaf is 78.73134328358209
# score for gini criterion, 9 max_depth, random splitter, 26 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 9 max_depth, random splitter, 26 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 9 max_depth, random splitter, 26 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 9 max_depth, random splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 9 max_depth, random splitter, 42 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for gini criterion, 9 max_depth, random splitter, 42 min_samples_split, 10 min_samples_leaf is 80.59701492537313
# score for gini criterion, 9 max_depth, random splitter, 42 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 9 max_depth, random splitter, 42 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 9 max_depth, random splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 82.46268656716418
# score for gini criterion, 10 max_depth, best splitter, 6 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 10 max_depth, best splitter, 6 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 10 max_depth, best splitter, 6 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, best splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, best splitter, 10 min_samples_split, 6 min_samples_leaf is 82.46268656716418
# score for gini criterion, 10 max_depth, best splitter, 10 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 10 max_depth, best splitter, 10 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 10 max_depth, best splitter, 10 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, best splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, best splitter, 16 min_samples_split, 6 min_samples_leaf is 79.85074626865672
# score for gini criterion, 10 max_depth, best splitter, 16 min_samples_split, 10 min_samples_leaf is 79.4776119402985
# score for gini criterion, 10 max_depth, best splitter, 16 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 10 max_depth, best splitter, 16 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, best splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, best splitter, 26 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 10 max_depth, best splitter, 26 min_samples_split, 10 min_samples_leaf is 79.85074626865672
# score for gini criterion, 10 max_depth, best splitter, 26 min_samples_split, 16 min_samples_leaf is 77.98507462686567
# score for gini criterion, 10 max_depth, best splitter, 26 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, best splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, best splitter, 42 min_samples_split, 6 min_samples_leaf is 79.1044776119403
# score for gini criterion, 10 max_depth, best splitter, 42 min_samples_split, 10 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, best splitter, 42 min_samples_split, 16 min_samples_leaf is 77.61194029850746
# score for gini criterion, 10 max_depth, best splitter, 42 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, best splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 77.98507462686567
# score for gini criterion, 10 max_depth, random splitter, 6 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 10 max_depth, random splitter, 6 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 10 max_depth, random splitter, 6 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 10 max_depth, random splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, random splitter, 10 min_samples_split, 6 min_samples_leaf is 77.98507462686567
# score for gini criterion, 10 max_depth, random splitter, 10 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 10 max_depth, random splitter, 10 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 10 max_depth, random splitter, 10 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 10 max_depth, random splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, random splitter, 16 min_samples_split, 6 min_samples_leaf is 80.97014925373135
# score for gini criterion, 10 max_depth, random splitter, 16 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for gini criterion, 10 max_depth, random splitter, 16 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 10 max_depth, random splitter, 16 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 10 max_depth, random splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, random splitter, 26 min_samples_split, 6 min_samples_leaf is 79.1044776119403
# score for gini criterion, 10 max_depth, random splitter, 26 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 10 max_depth, random splitter, 26 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 10 max_depth, random splitter, 26 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 10 max_depth, random splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for gini criterion, 10 max_depth, random splitter, 42 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for gini criterion, 10 max_depth, random splitter, 42 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for gini criterion, 10 max_depth, random splitter, 42 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for gini criterion, 10 max_depth, random splitter, 42 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for gini criterion, 10 max_depth, random splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 3 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 80.97014925373135
# score for entropy criterion, 3 max_depth, best splitter, 6 min_samples_split, 10 min_samples_leaf is 80.97014925373135
# score for entropy criterion, 3 max_depth, best splitter, 6 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 3 max_depth, best splitter, 6 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 3 max_depth, best splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 3 max_depth, best splitter, 10 min_samples_split, 6 min_samples_leaf is 80.97014925373135
# score for entropy criterion, 3 max_depth, best splitter, 10 min_samples_split, 10 min_samples_leaf is 80.97014925373135
# score for entropy criterion, 3 max_depth, best splitter, 10 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# ...
# score for entropy criterion, 8 max_depth, best splitter, 26 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 8 max_depth, best splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 8 max_depth, best splitter, 42 min_samples_split, 6 min_samples_leaf is 82.08955223880596
# score for entropy criterion, 8 max_depth, best splitter, 42 min_samples_split, 10 min_samples_leaf is 80.59701492537313
# score for entropy criterion, 8 max_depth, best splitter, 42 min_samples_split, 16 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 8 max_depth, best splitter, 42 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 8 max_depth, best splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 8 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 77.98507462686567
# score for entropy criterion, 8 max_depth, random splitter, 6 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for entropy criterion, 8 max_depth, random splitter, 6 min_samples_split, 16 min_samples_leaf is 80.59701492537313
# score for entropy criterion, 8 max_depth, random splitter, 6 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 8 max_depth, random splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 8 max_depth, random splitter, 10 min_samples_split, 6 min_samples_leaf is 77.98507462686567
# score for entropy criterion, 8 max_depth, random splitter, 10 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for entropy criterion, 8 max_depth, random splitter, 10 min_samples_split, 16 min_samples_leaf is 80.59701492537313
# score for entropy criterion, 8 max_depth, random splitter, 10 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 8 max_depth, random splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 8 max_depth, random splitter, 16 min_samples_split, 6 min_samples_leaf is 79.85074626865672
# score for entropy criterion, 8 max_depth, random splitter, 16 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for entropy criterion, 8 max_depth, random splitter, 16 min_samples_split, 16 min_samples_leaf is 80.59701492537313
# score for entropy criterion, 8 max_depth, random splitter, 16 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 8 max_depth, random splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 8 max_depth, random splitter, 26 min_samples_split, 6 min_samples_leaf is 78.73134328358209
# score for entropy criterion, 8 max_depth, random splitter, 26 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 8 max_depth, random splitter, 26 min_samples_split, 16 min_samples_leaf is 80.59701492537313
# score for entropy criterion, 8 max_depth, random splitter, 26 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 8 max_depth, random splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 8 max_depth, random splitter, 42 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 8 max_depth, random splitter, 42 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 8 max_depth, random splitter, 42 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 8 max_depth, random splitter, 42 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 8 max_depth, random splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 83.2089552238806
# score for entropy criterion, 9 max_depth, best splitter, 6 min_samples_split, 10 min_samples_leaf is 80.97014925373135
# score for entropy criterion, 9 max_depth, best splitter, 6 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 9 max_depth, best splitter, 6 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, best splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, best splitter, 10 min_samples_split, 6 min_samples_leaf is 83.2089552238806
# score for entropy criterion, 9 max_depth, best splitter, 10 min_samples_split, 10 min_samples_leaf is 80.97014925373135
# score for entropy criterion, 9 max_depth, best splitter, 10 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 9 max_depth, best splitter, 10 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, best splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, best splitter, 16 min_samples_split, 6 min_samples_leaf is 83.2089552238806
# score for entropy criterion, 9 max_depth, best splitter, 16 min_samples_split, 10 min_samples_leaf is 80.97014925373135
# score for entropy criterion, 9 max_depth, best splitter, 16 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 9 max_depth, best splitter, 16 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, best splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, best splitter, 26 min_samples_split, 6 min_samples_leaf is 82.83582089552239
# score for entropy criterion, 9 max_depth, best splitter, 26 min_samples_split, 10 min_samples_leaf is 80.97014925373135
# score for entropy criterion, 9 max_depth, best splitter, 26 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 9 max_depth, best splitter, 26 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, best splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, best splitter, 42 min_samples_split, 6 min_samples_leaf is 81.34328358208955
# score for entropy criterion, 9 max_depth, best splitter, 42 min_samples_split, 10 min_samples_leaf is 80.59701492537313
# score for entropy criterion, 9 max_depth, best splitter, 42 min_samples_split, 16 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, best splitter, 42 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, best splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for entropy criterion, 9 max_depth, random splitter, 6 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for entropy criterion, 9 max_depth, random splitter, 6 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 9 max_depth, random splitter, 6 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 9 max_depth, random splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, random splitter, 10 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for entropy criterion, 9 max_depth, random splitter, 10 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for entropy criterion, 9 max_depth, random splitter, 10 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 9 max_depth, random splitter, 10 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 9 max_depth, random splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, random splitter, 16 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 9 max_depth, random splitter, 16 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for entropy criterion, 9 max_depth, random splitter, 16 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 9 max_depth, random splitter, 16 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 9 max_depth, random splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, random splitter, 26 min_samples_split, 6 min_samples_leaf is 78.73134328358209
# score for entropy criterion, 9 max_depth, random splitter, 26 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 9 max_depth, random splitter, 26 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 9 max_depth, random splitter, 26 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 9 max_depth, random splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 9 max_depth, random splitter, 42 min_samples_split, 6 min_samples_leaf is 80.59701492537313
# score for entropy criterion, 9 max_depth, random splitter, 42 min_samples_split, 10 min_samples_leaf is 80.59701492537313
# score for entropy criterion, 9 max_depth, random splitter, 42 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 9 max_depth, random splitter, 42 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 9 max_depth, random splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 83.95522388059702
# score for entropy criterion, 10 max_depth, best splitter, 6 min_samples_split, 10 min_samples_leaf is 80.97014925373135
# score for entropy criterion, 10 max_depth, best splitter, 6 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 10 max_depth, best splitter, 6 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, best splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, best splitter, 10 min_samples_split, 6 min_samples_leaf is 83.95522388059702
# score for entropy criterion, 10 max_depth, best splitter, 10 min_samples_split, 10 min_samples_leaf is 80.97014925373135
# score for entropy criterion, 10 max_depth, best splitter, 10 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 10 max_depth, best splitter, 10 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, best splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, best splitter, 16 min_samples_split, 6 min_samples_leaf is 83.95522388059702
# score for entropy criterion, 10 max_depth, best splitter, 16 min_samples_split, 10 min_samples_leaf is 80.97014925373135
# score for entropy criterion, 10 max_depth, best splitter, 16 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 10 max_depth, best splitter, 16 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, best splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, best splitter, 26 min_samples_split, 6 min_samples_leaf is 83.58208955223881
# score for entropy criterion, 10 max_depth, best splitter, 26 min_samples_split, 10 min_samples_leaf is 80.97014925373135
# score for entropy criterion, 10 max_depth, best splitter, 26 min_samples_split, 16 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 10 max_depth, best splitter, 26 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, best splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, best splitter, 42 min_samples_split, 6 min_samples_leaf is 81.34328358208955
# score for entropy criterion, 10 max_depth, best splitter, 42 min_samples_split, 10 min_samples_leaf is 80.59701492537313
# score for entropy criterion, 10 max_depth, best splitter, 42 min_samples_split, 16 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, best splitter, 42 min_samples_split, 26 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, best splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, random splitter, 6 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for entropy criterion, 10 max_depth, random splitter, 6 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 10 max_depth, random splitter, 6 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 10 max_depth, random splitter, 6 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, random splitter, 10 min_samples_split, 6 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, random splitter, 10 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for entropy criterion, 10 max_depth, random splitter, 10 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 10 max_depth, random splitter, 10 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 10 max_depth, random splitter, 10 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, random splitter, 16 min_samples_split, 6 min_samples_leaf is 77.61194029850746
# score for entropy criterion, 10 max_depth, random splitter, 16 min_samples_split, 10 min_samples_leaf is 82.46268656716418
# score for entropy criterion, 10 max_depth, random splitter, 16 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 10 max_depth, random splitter, 16 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 10 max_depth, random splitter, 16 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, random splitter, 26 min_samples_split, 6 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 10 max_depth, random splitter, 26 min_samples_split, 10 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 10 max_depth, random splitter, 26 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 10 max_depth, random splitter, 26 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 10 max_depth, random splitter, 26 min_samples_split, 42 min_samples_leaf is 78.35820895522389
# score for entropy criterion, 10 max_depth, random splitter, 42 min_samples_split, 6 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 10 max_depth, random splitter, 42 min_samples_split, 10 min_samples_leaf is 80.59701492537313
# score for entropy criterion, 10 max_depth, random splitter, 42 min_samples_split, 16 min_samples_leaf is 80.22388059701493
# score for entropy criterion, 10 max_depth, random splitter, 42 min_samples_split, 26 min_samples_leaf is 79.1044776119403
# score for entropy criterion, 10 max_depth, random splitter, 42 min_samples_split, 42 min_samples_leaf is 78.35820895522389

# %%
'''
score for gini criterion, 3 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 82.08955223880596
score for gini criterion, 4 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 82.46268656716418
score for entropy criterion, 7 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 83.58208955223881
score for entropy criterion, 8 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 83.95522388059702
score for entropy criterion, 9 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 83.2089552238806
'''
# Out:
# '\nscore for gini criterion, 3 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 82.08955223880596\nscore for gini criterion, 4 max_depth, random splitter, 6 min_samples_split, 6 min_samples_leaf is 82.46268656716418\nscore for entropy criterion, 7 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 83.58208955223881\nscore for entropy criterion, 8 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 83.95522388059702\nscore for entropy criterion, 9 max_depth, best splitter, 6 min_samples_split, 6 min_samples_leaf is 83.2089552238806\n'

# %%
clf_tuned = DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
                                max_features=None, max_leaf_nodes=None, min_samples_leaf=6,
                                min_samples_split=6, min_weight_fraction_leaf=0.0,
                                presort=False, random_state=100, splitter='random')
clf_tuned.fit(X_train, y_train)
y_pred = clf_tuned.predict(X_cv)
y_test_pred = clf_tuned.predict(X_test)
score_in_percent(y_pred,y_cv)
# Out:
# 82.462686567164184

# %%
# This statement builds a dot file.
cols = list(X_train.columns.values)
tree.export_graphviz(clf_tuned, out_file='tunedtreewithdummies.dot',feature_names  = cols)

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": y_test_pred
    })
submission.to_csv('tunedtreewithdummies.csv', index=False) # LB : 0.74163
